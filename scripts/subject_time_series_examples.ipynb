# %%
import pandas as pd
from plot_utils import patient_glucose_examples_plot

color_palette = ['#C0D6CA',
                 '#78ACA8',
                 '#2D6B8F',
                 '#235796',
                 '#E7C4C0',
                 '#E3A39A',
                 '#CA6F6A',
                 '#7B3841',
                 '#D5BC67',
                 '#20425B',
                 '#E77A5B',
                 '#9C9DB2',
                ]

# %%
data = pd.read_csv('../datasets/ohiot1dm_exog_9_day_test.csv')
data.ds = pd.to_datetime(data.ds, format='%Y-%m-%d %H:%M:%S')

ids = ['#552',
       '#559',
       '#563',
       '#567', 
       '#575', 
       '#584', 
       ]

patient_glucose_examples_plot(data, ids, color_palette, xlim=10, ylim=450, insulin_scale=15, save_dir=None)
# Out:
# /home/extra_scratch/wpotosna/neuralforecast_CHIL2025/plots/plot_utils.py:153: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax_right.set_yticklabels([f'{i:.2f}' for i in np.round(np.linspace(0, 400/insulin_scale, 3), 1)])

# %%
data = pd.read_csv('../datasets/simglucose_exog_9_day_test.csv')
data.ds = pd.to_datetime(data.ds, format='%Y-%m-%d %H:%M:%S')

ids = ['adult#001', 
       'adult#002', 
       'adolescent#001', 
       'adolescent#002', 
       'child#001', 
       'child#002'
      ]

# %%
patient_glucose_examples_plot(data, ids, color_palette, xlim=10, ylim=450, insulin_scale=100, save_dir=None)
# Out:
# /home/extra_scratch/wpotosna/neuralforecast_CHIL2025/plots/plot_utils.py:153: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax_right.set_yticklabels([f'{i:.2f}' for i in np.round(np.linspace(0, 400/insulin_scale, 3), 1)])
