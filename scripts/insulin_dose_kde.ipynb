# %%
import pandas as pd
from plot_utils import insulin_kde_plots

color_palette = ['#C0D6CA',
                 '#78ACA8',
                 '#2D6B8F',
                 '#235796',
                 '#E7C4C0',
                 '#E3A39A',
                 '#CA6F6A',
                 '#7B3841',
                 '#D5BC67',
                 '#20425B',
                 '#E77A5B',
                 '#9C9DB2',
                ]

# %%
df1 = pd.read_csv('../datasets/ohiot1dm_exog_9_day_test.csv')
ids = ['#559', '#563', '#570', '#575', 
        '#588', '#591', '#540', '#544',
        '#552', '#567', '#584', '#596']

insulin_kde_plots(df1, ids, color_palette, xlim=20, save_dir=None)

# %%
df2 = pd.read_csv('../datasets/simglucose_exog_9_day_test.csv')
ids = ['adolescent#001', 'adolescent#002', 'adolescent#008', 'adolescent#010',
        'adult#001', 'adult#002', 'adult#008', 'adult#010',
        'child#001', 'child#002', 'child#008', 'child#010'
      ]

insulin_kde_plots(df2, ids, color_palette, xlim=10, save_dir=None)
